# %% [markdown]
# ## Demo: Denoising of Multiple Noise Levels Mouse Brain Cortex Images
# This notebook demonstrates training an EMDiffuse-n model for a 2D denoising task. Note that training a neural network for actual use should be done with **more training time and more training data** as used here.

# %% [markdown]
# ## Set the Runtime Type on Google Colab
#
# Set the Runtime type: Go to Runtime -> Change the Runtime type
#
# Runtime type: Python 3 (Python 3 is programming language in which this program is written)
#
# Accelator: GPU (Graphics processing unit (GPU)

# %% [markdown]
# ## Download and Install EMDiffuse

# %%
# !git clone https://github.com/Luchixiang/EMDiffuse
# %cd EMDiffuse/
# !pip install -r requirements.txt
# Out:
# Cloning into 'EMDiffuse'...
# remote: Enumerating objects: 741, done.
# remote: Counting objects: 100% (88/88), done.
# remote: Compressing objects: 100% (49/49), done.
# remote: Total 741 (delta 42), reused 75 (delta 35), pack-reused 653
# Receiving objects: 100% (741/741), 54.76 MiB | 14.08 MiB/s, done.
# Resolving deltas: 100% (340/340), done.
# /home/cxlu/EMDiffuse/example/denoise/EMDiffuse
# Requirement already satisfied: torch>=1.13.0 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from -r requirements.txt (line 1)) (2.2.0)
# Requirement already satisfied: torchvision>=0.14.0 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from -r requirements.txt (line 2)) (0.17.0)
# Requirement already satisfied: matplotlib in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from -r requirements.txt (line 3)) (3.7.5)
# Requirement already satisfied: tensorboard in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from -r requirements.txt (line 4)) (2.14.0)
# Requirement already satisfied: scipy in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from -r requirements.txt (line 5)) (1.10.1)
# Requirement already satisfied: tifffile in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from -r requirements.txt (line 6)) (2023.7.10)
# Requirement already satisfied: opencv-python in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from -r requirements.txt (line 7)) (4.9.0.80)
# Requirement already satisfied: pandas in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from -r requirements.txt (line 8)) (2.0.3)
# Requirement already satisfied: imutils in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from -r requirements.txt (line 9)) (0.5.4)
# Requirement already satisfied: image_registration in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from -r requirements.txt (line 10)) (0.2.8)
# Requirement already satisfied: numpy>=1.23.0 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from -r requirements.txt (line 11)) (1.24.4)
# Requirement already satisfied: pytest in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from -r requirements.txt (line 12)) (8.0.1)
# Requirement already satisfied: warmup_scheduler in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from -r requirements.txt (line 13)) (0.3)
# Requirement already satisfied: tqdm in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from -r requirements.txt (line 14)) (4.66.2)
# Requirement already satisfied: gradio==3.34.0 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from -r requirements.txt (line 15)) (3.34.0)
# Requirement already satisfied: aiofiles in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from gradio==3.34.0->-r requirements.txt (line 15)) (23.2.1)
# Requirement already satisfied: aiohttp in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from gradio==3.34.0->-r requirements.txt (line 15)) (3.9.3)
# Requirement already satisfied: altair>=4.2.0 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from gradio==3.34.0->-r requirements.txt (line 15)) (5.2.0)
# Requirement already satisfied: fastapi in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from gradio==3.34.0->-r requirements.txt (line 15)) (0.109.2)
# Requirement already satisfied: ffmpy in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from gradio==3.34.0->-r requirements.txt (line 15)) (0.3.2)
# Requirement already satisfied: gradio-client>=0.2.6 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from gradio==3.34.0->-r requirements.txt (line 15)) (0.10.0)
# Requirement already satisfied: httpx in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from gradio==3.34.0->-r requirements.txt (line 15)) (0.26.0)
# Requirement already satisfied: huggingface-hub>=0.14.0 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from gradio==3.34.0->-r requirements.txt (line 15)) (0.20.3)
# Requirement already satisfied: jinja2 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from gradio==3.34.0->-r requirements.txt (line 15)) (3.1.3)
# Requirement already satisfied: markdown-it-py>=2.0.0 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from markdown-it-py[linkify]>=2.0.0->gradio==3.34.0->-r requirements.txt (line 15)) (2.2.0)
# Requirement already satisfied: markupsafe in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from gradio==3.34.0->-r requirements.txt (line 15)) (2.1.5)
# Requirement already satisfied: mdit-py-plugins<=0.3.3 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from gradio==3.34.0->-r requirements.txt (line 15)) (0.3.3)
# Requirement already satisfied: orjson in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from gradio==3.34.0->-r requirements.txt (line 15)) (3.9.14)
# Requirement already satisfied: pillow in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from gradio==3.34.0->-r requirements.txt (line 15)) (10.2.0)
# Requirement already satisfied: pydantic in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from gradio==3.34.0->-r requirements.txt (line 15)) (2.6.1)
# Requirement already satisfied: pydub in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from gradio==3.34.0->-r requirements.txt (line 15)) (0.25.1)
# Requirement already satisfied: pygments>=2.12.0 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from gradio==3.34.0->-r requirements.txt (line 15)) (2.17.2)
# Requirement already satisfied: python-multipart in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from gradio==3.34.0->-r requirements.txt (line 15)) (0.0.9)
# Requirement already satisfied: pyyaml in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from gradio==3.34.0->-r requirements.txt (line 15)) (6.0.1)
# Requirement already satisfied: requests in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from gradio==3.34.0->-r requirements.txt (line 15)) (2.31.0)
# Requirement already satisfied: semantic-version in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from gradio==3.34.0->-r requirements.txt (line 15)) (2.10.0)
# Requirement already satisfied: typing-extensions in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from gradio==3.34.0->-r requirements.txt (line 15)) (4.9.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from gradio==3.34.0->-r requirements.txt (line 15)) (0.27.1)
# Requirement already satisfied: websockets>=10.0 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from gradio==3.34.0->-r requirements.txt (line 15)) (11.0.3)
# Requirement already satisfied: filelock in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from torch>=1.13.0->-r requirements.txt (line 1)) (3.13.1)
# Requirement already satisfied: sympy in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from torch>=1.13.0->-r requirements.txt (line 1)) (1.12)
# Requirement already satisfied: networkx in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from torch>=1.13.0->-r requirements.txt (line 1)) (3.1)
# Requirement already satisfied: fsspec in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from torch>=1.13.0->-r requirements.txt (line 1)) (2024.2.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from torch>=1.13.0->-r requirements.txt (line 1)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from torch>=1.13.0->-r requirements.txt (line 1)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from torch>=1.13.0->-r requirements.txt (line 1)) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from torch>=1.13.0->-r requirements.txt (line 1)) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from torch>=1.13.0->-r requirements.txt (line 1)) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from torch>=1.13.0->-r requirements.txt (line 1)) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from torch>=1.13.0->-r requirements.txt (line 1)) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from torch>=1.13.0->-r requirements.txt (line 1)) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from torch>=1.13.0->-r requirements.txt (line 1)) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from torch>=1.13.0->-r requirements.txt (line 1)) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from torch>=1.13.0->-r requirements.txt (line 1)) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from torch>=1.13.0->-r requirements.txt (line 1)) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13.0->-r requirements.txt (line 1)) (12.3.101)
# Requirement already satisfied: contourpy>=1.0.1 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 3)) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 3)) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 3)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 3)) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 3)) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 3)) (6.1.1)
# Requirement already satisfied: absl-py>=0.4 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from tensorboard->-r requirements.txt (line 4)) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from tensorboard->-r requirements.txt (line 4)) (1.60.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from tensorboard->-r requirements.txt (line 4)) (2.28.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from tensorboard->-r requirements.txt (line 4)) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from tensorboard->-r requirements.txt (line 4)) (3.5.2)
# Requirement already satisfied: protobuf>=3.19.6 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from tensorboard->-r requirements.txt (line 4)) (4.25.3)
# Requirement already satisfied: setuptools>=41.0.0 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from tensorboard->-r requirements.txt (line 4)) (68.2.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from tensorboard->-r requirements.txt (line 4)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from tensorboard->-r requirements.txt (line 4)) (3.0.1)
# Requirement already satisfied: wheel>=0.26 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from tensorboard->-r requirements.txt (line 4)) (0.41.2)
# Requirement already satisfied: pytz>=2020.1 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from pandas->-r requirements.txt (line 8)) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from pandas->-r requirements.txt (line 8)) (2024.1)
# Requirement already satisfied: astropy in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from image_registration->-r requirements.txt (line 10)) (5.2.2)
# Requirement already satisfied: iniconfig in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from pytest->-r requirements.txt (line 12)) (2.0.0)
# Requirement already satisfied: pluggy<2.0,>=1.3.0 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from pytest->-r requirements.txt (line 12)) (1.4.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from pytest->-r requirements.txt (line 12)) (1.2.0)
# Requirement already satisfied: tomli>=1.0.0 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from pytest->-r requirements.txt (line 12)) (2.0.1)
# Requirement already satisfied: jsonschema>=3.0 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from altair>=4.2.0->gradio==3.34.0->-r requirements.txt (line 15)) (4.21.1)
# Requirement already satisfied: toolz in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from altair>=4.2.0->gradio==3.34.0->-r requirements.txt (line 15)) (0.12.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard->-r requirements.txt (line 4)) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard->-r requirements.txt (line 4)) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard->-r requirements.txt (line 4)) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->-r requirements.txt (line 4)) (1.3.1)
# Requirement already satisfied: zipp>=3.1.0 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib->-r requirements.txt (line 3)) (3.17.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard->-r requirements.txt (line 4)) (7.0.1)
# Requirement already satisfied: mdurl~=0.1 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from markdown-it-py>=2.0.0->markdown-it-py[linkify]>=2.0.0->gradio==3.34.0->-r requirements.txt (line 15)) (0.1.2)
# Requirement already satisfied: linkify-it-py<3,>=1 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from markdown-it-py[linkify]>=2.0.0->gradio==3.34.0->-r requirements.txt (line 15)) (2.0.3)
# Requirement already satisfied: six>=1.5 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib->-r requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from requests->gradio==3.34.0->-r requirements.txt (line 15)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from requests->gradio==3.34.0->-r requirements.txt (line 15)) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from requests->gradio==3.34.0->-r requirements.txt (line 15)) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from requests->gradio==3.34.0->-r requirements.txt (line 15)) (2024.2.2)
# Requirement already satisfied: click>=7.0 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from uvicorn>=0.14.0->gradio==3.34.0->-r requirements.txt (line 15)) (8.1.7)
# Requirement already satisfied: h11>=0.8 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from uvicorn>=0.14.0->gradio==3.34.0->-r requirements.txt (line 15)) (0.14.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from aiohttp->gradio==3.34.0->-r requirements.txt (line 15)) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from aiohttp->gradio==3.34.0->-r requirements.txt (line 15)) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from aiohttp->gradio==3.34.0->-r requirements.txt (line 15)) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from aiohttp->gradio==3.34.0->-r requirements.txt (line 15)) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from aiohttp->gradio==3.34.0->-r requirements.txt (line 15)) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from aiohttp->gradio==3.34.0->-r requirements.txt (line 15)) (4.0.3)
# Requirement already satisfied: pyerfa>=2.0 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from astropy->image_registration->-r requirements.txt (line 10)) (2.0.0.3)
# Requirement already satisfied: starlette<0.37.0,>=0.36.3 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from fastapi->gradio==3.34.0->-r requirements.txt (line 15)) (0.36.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from pydantic->gradio==3.34.0->-r requirements.txt (line 15)) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from pydantic->gradio==3.34.0->-r requirements.txt (line 15)) (2.16.2)
# Requirement already satisfied: anyio in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from httpx->gradio==3.34.0->-r requirements.txt (line 15)) (4.2.0)
# Requirement already satisfied: httpcore==1.* in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from httpx->gradio==3.34.0->-r requirements.txt (line 15)) (1.0.3)
# Requirement already satisfied: sniffio in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from httpx->gradio==3.34.0->-r requirements.txt (line 15)) (1.3.0)
# Requirement already satisfied: mpmath>=0.19 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from sympy->torch>=1.13.0->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from jsonschema>=3.0->altair>=4.2.0->gradio==3.34.0->-r requirements.txt (line 15)) (2023.12.1)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from jsonschema>=3.0->altair>=4.2.0->gradio==3.34.0->-r requirements.txt (line 15)) (1.3.10)
# Requirement already satisfied: referencing>=0.28.4 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from jsonschema>=3.0->altair>=4.2.0->gradio==3.34.0->-r requirements.txt (line 15)) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from jsonschema>=3.0->altair>=4.2.0->gradio==3.34.0->-r requirements.txt (line 15)) (0.18.0)
# Requirement already satisfied: uc-micro-py in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from linkify-it-py<3,>=1->markdown-it-py[linkify]>=2.0.0->gradio==3.34.0->-r requirements.txt (line 15)) (1.0.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->-r requirements.txt (line 4)) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->-r requirements.txt (line 4)) (3.2.2)

# %% [markdown]
# Note: Before starting, ensure that you're working within the 'EMDiffuse' directory. The directory can be checked with the `!pwd` command and adjusted with the `%cd` command.

# %%
# %cd ../..

# %%
import sys
import os
sys.path.append('RAFT/core')
from RAFT.core.raftConfig import RaftConfig
from RAFT.core.register import registration
import urllib
import zipfile
import glob
from tifffile import imread, imwrite
import matplotlib.pyplot as plt

# %% [markdown]
# ## Download the Demo Data
#
# We'll be working with a set of example images that show different areas of a mouse's brain cortex.
#
#
# The high SNR images (Brain__4w_09.tif) are acquisitions with dwell time 36 µs and the low SNR images were acquired with a dwell time of 0.5 µs (Brain__4w_04.tif), 1 µs (Brain__4w_05.tif), 1.5 µs (Brain__4w_06.tif), 2 µs (Brain__4w_07.tif), 4 µs (Brain__4w_08.tif).

# %%
if not os.path.isdir('./dataset'):
    os.mkdir('./dataset')

# Here, we only download the demo training dataset. To download the whole dataset, replace the URL with https://zenodo.org/records/10205819/files/EMDiffuse_dataset.zip?download=1.
zipPath="dataset/EMDiffuse_data_demo.zip"
if not os.path.exists(zipPath):
    #download and unzip data
    data = urllib.request.urlretrieve('https://zenodo.org/records/10720576/files/EMDiffuse_dataset_demo.zip?download=1', zipPath)
    with zipfile.ZipFile(zipPath, 'r') as zip_ref:
        zip_ref.extractall("dataset")

# %%
dataset_path = './dataset/EMDiffuse_dataset_demo/brain_train'
subdir = glob.glob(os.path.join(dataset_path, '*'))
example_image_noise1 = imread(os.path.join(subdir[0], 'Brain__4w_05.tif'))
example_image_noise2 = imread(os.path.join(subdir[0], 'Brain__4w_07.tif'))
example_image_gt = imread(os.path.join(subdir[0], 'Brain__4w_09.tif'))
plt.figure(figsize=(14,7))
plt.subplot(1,3,1)
plt.imshow(example_image_noise1, cmap='gray')
plt.title('Noise Level 2')
plt.subplot(1,3,2)
plt.imshow(example_image_noise2, cmap='gray')
plt.title('Noise Level 4')
plt.subplot(1,3,3)
plt.imshow(example_image_gt, cmap='gray')
plt.title('Ground Truth')
# Out:
# Text(0.5, 1.0, 'Ground Truth')

# %% [markdown]
# ## Generate Training Data for EMDiffuse-n
# Due to the inherent distortion and drift during the EM imaging, each image pair should be registered using optical flow to train the neural network.
#
# We first need to create a `RaftConfig` object, which defines how to get the pairs of low/high SNR images.
# Key arguments:
#  - path: The folder where training images are stored.
#  - patch_size: Since we can't always use the whole image at once, we cut it into smaller ones. As a general rule, use a patch size with a power of two along all axes or at least divisible by 8. For this example, we will use patches of 256x256.
#  - overlap: Overlap ratio of adjacent patches. For this example, we will use an overlap ratio of 0.125 (i.e., 32 pixels).
#  - border: The region to be discarded around the edges after alignment, ensuring our training focus remains on the meaningful data.

# %%
dataset_path = './dataset/EMDiffuse_dataset_demo/brain_train'
# Set the optical flow registration and crop config
register_config = RaftConfig(path=dataset_path, patch_size=256, border=32, overlap=0.125)
# Start registration and cropping
registration(register_config)
# Out:
# processing image 32, Brain__4w_07.tif
# /home/cxlu/anaconda3/envs/EMDiffuse_test/lib/python3.8/site-packages/torch/functional.py:507: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3549.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# processing image 32, Brain__4w_05.tif
# processing image 32, Brain__4w_06.tif
# processing image 32, Brain__4w_08.tif
# processing image 32, Brain__4w_04.tif
# processing image 35, Brain__4w_07.tif
# processing image 35, Brain__4w_05.tif
# processing image 35, Brain__4w_06.tif
# processing image 35, Brain__4w_08.tif
# processing image 35, Brain__4w_04.tif
# processing image 50, Brain__4w_07.tif
# processing image 50, Brain__4w_05.tif
# processing image 50, Brain__4w_06.tif
# processing image 50, Brain__4w_08.tif
# processing image 50, Brain__4w_04.tif
# processing image 51, Brain__4w_07.tif
# processing image 51, Brain__4w_05.tif
# processing image 51, Brain__4w_06.tif
# processing image 51, Brain__4w_08.tif
# processing image 51, Brain__4w_04.tif
# processing image 56, Brain__4w_07.tif
# processing image 56, Brain__4w_05.tif
# processing image 56, Brain__4w_06.tif
# processing image 56, Brain__4w_08.tif
# processing image 56, Brain__4w_04.tif
# processing image 57, Brain__4w_07.tif
# processing image 57, Brain__4w_05.tif
# processing image 57, Brain__4w_06.tif
# processing image 57, Brain__4w_08.tif
# processing image 57, Brain__4w_04.tif
# processing image 58, Brain__4w_07.tif
# processing image 58, Brain__4w_05.tif
# processing image 58, Brain__4w_06.tif
# processing image 58, Brain__4w_08.tif
# processing image 58, Brain__4w_04.tif
# processing image 60, Brain__4w_07.tif
# processing image 60, Brain__4w_05.tif
# processing image 60, Brain__4w_06.tif
# processing image 60, Brain__4w_08.tif
# processing image 60, Brain__4w_04.tif
# processing image 67, Brain__4w_07.tif
# processing image 67, Brain__4w_05.tif
# processing image 67, Brain__4w_06.tif
# processing image 67, Brain__4w_08.tif
# processing image 67, Brain__4w_04.tif
# processing image 68, Brain__4w_07.tif
# processing image 68, Brain__4w_05.tif
# processing image 68, Brain__4w_06.tif
# processing image 68, Brain__4w_08.tif
# processing image 68, Brain__4w_04.tif
# processing image 69, Brain__4w_07.tif
# processing image 69, Brain__4w_05.tif
# processing image 69, Brain__4w_06.tif
# processing image 69, Brain__4w_08.tif
# processing image 69, Brain__4w_04.tif

# %% [markdown]
# The `registration` function will now register the noisy image with ground truth and generate lots of paired patches that will be used for training the EMDiffuse-n model later. The Cropped patch should be stored at the `denoise` folder within the dataset directory.

# %% [markdown]
# ## Show Example Patches

# %%
noise_images = glob.glob(os.path.join(dataset_path, 'denoise', 'train_wf', '*', '*', '*.tif'))
if len(noise_images) != 0:
    for i in range(3):
        noisy_img =  imread(noise_images[i])
        gt_img = imread(noise_images[i].replace('train_wf', 'train_gt'))
        plt.figure(figsize=(14,7))
        plt.subplot(1,2,1)
        plt.imshow(noisy_img, cmap='gray')
        plt.title('Noisy Patch')
        plt.subplot(1,2,2)
        plt.imshow(gt_img, cmap='gray')
        plt.title('Ground Truth Patch')

# %%
import core.praser as Praser
import os
import warnings
import torch
import torch.multiprocessing as mp

from core.logger import VisualWriter, InfoLogger
import core.praser as Praser
import core.util as Util
from data import define_dataloader
from models import create_EMDiffuse
from emdiffuse_conifg import EMDiffuseConfig
from run import main_worker

# %% [markdown]
# ## Configuring the EMDiffuse Model and Training
# Before we construct the actual EMDiffuse model, we have to define the model and training configurations via an `EMDiffuseConfig` object, which includes：
# - path: The location of the training patches that have been aligned and cropped.
# - lr: The learning rate.
# - config: Some basic parameters of the model and the dataset, including the network architecture, loss function, and noise scheduler of diffusion. Please see the JSON files for more details.
# - batch_size: Training batch size on every gpu.
# - phase: The mode of operation, either train or test.

# %%
config = EMDiffuseConfig(config='config/EMDiffuse-n.json', phase='train', 
                         path='./dataset/EMDiffuse_dataset_demo/brain_train/denoise/train_wf', batch_size=4, lr=5e-5)
opt = Praser.parse(config) # Parse the config
opt['world_size'] = 1 
Util.set_seed(opt['seed'])
model = create_EMDiffuse(opt)
print(f'length of training data loader: {len(model.phase_loader)}, length of validation dataloader: {len(model.val_loader)}')
# Out:
# results and model will be saved in experiments/train_EMDiffuse-n_240220_184213
# length of training data loader: 144, length of validation dataloader: 26

# %% [markdown]
# ## Training
# Training the model will likely take some time. Both the model's state and its training metrics are automatically saved within a newly created directory, `./experiments/train_EMDiffuse-n_time`, as logged above. Here, `time` is a placeholder for the actual timestamp when the training session begins, ensuring each training session is uniquely identifiable.
#
#
# Furthermore, you can look at the predictions for some of the validation images, which can help recognize problems early on.

# %%
model.train()
# Out:
# epoch 1: training start
# epoch 2: training start
